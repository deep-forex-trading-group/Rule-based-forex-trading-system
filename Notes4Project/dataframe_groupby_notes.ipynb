# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import pandas as pd

# %%
# %%time
yht_rc_df = pd.read_csv("../data/yht_eur_big_table.csv", index_col=["dt_point_holding"])
yht_rc_df.head()
# Out:
# CPU times: user 160 ms, sys: 8.15 ms, total: 168 ms
# Wall time: 168 ms
#                      symbol action  lots            open_date  \
# dt_point_holding
# 2020-10-14 10:05:00  EURUSD   sell  0.01  2020-10-14 10:08:18
# 2020-10-14 10:10:00  EURUSD   sell  0.01  2020-10-14 10:08:18
# 2020-10-14 10:15:00  EURUSD   sell  0.01  2020-10-14 10:08:18
# 2020-10-14 10:20:00  EURUSD   sell  0.01  2020-10-14 10:08:18
# 2020-10-14 10:25:00  EURUSD   sell  0.01  2020-10-14 10:08:18
#
#                               close_date  open_price  close_price  profits  \
# dt_point_holding
# 2020-10-14 10:05:00  2020-10-14 12:31:20     1.17321      1.17625    -3.04
# 2020-10-14 10:10:00  2020-10-14 12:31:20     1.17321      1.17625    -3.04
# 2020-10-14 10:15:00  2020-10-14 12:31:20     1.17321      1.17625    -3.04
# 2020-10-14 10:20:00  2020-10-14 12:31:20     1.17321      1.17625    -3.04
# 2020-10-14 10:25:00  2020-10-14 12:31:20     1.17321      1.17625    -3.04
#
# ...

# %%
# dataframe groupby + agg + rename

# %%
yht_rc_df_cnt = yht_rc_df.groupby(by=[yht_rc_df.index], dropna=False).agg(cur_holding_cnt=("symbol", "count"))
yht_rc_df_cnt[yht_rc_df_cnt["cur_holding_cnt"]>=10]
# Out:
#                      cur_holding_cnt
# dt_point_holding
# 2020-10-20 14:10:00               10
# 2020-10-20 14:15:00               11
# 2020-10-20 14:20:00               11
# 2020-10-20 14:25:00               11
# 2020-10-20 14:30:00               11
# ...                              ...
# 2021-06-17 01:35:00               10
# 2021-06-17 01:40:00               10
# 2021-06-17 01:45:00               10
# 2021-06-17 01:50:00               10
# 2021-06-17 01:55:00               10
#
# [3321 rows x 1 columns]
