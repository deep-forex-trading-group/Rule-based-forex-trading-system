# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import pandas as pd

# %%
# %%time
yht_rc_df = pd.read_csv("../data/yht_eur_bit_table.csv", index_col=["dt_point_holding"])
yht_rc_df.head()
# Out:
# CPU times: user 142 ms, sys: 28.2 ms, total: 170 ms
# Wall time: 170 ms
#                      symbol action  lots            open_date  \
# dt_point_holding
# 2020-10-14 10:05:00  EURUSD   sell  0.01  2020-10-14 10:08:18
# 2020-10-14 10:10:00  EURUSD   sell  0.01  2020-10-14 10:08:18
# 2020-10-14 10:15:00  EURUSD   sell  0.01  2020-10-14 10:08:18
# 2020-10-14 10:20:00  EURUSD   sell  0.01  2020-10-14 10:08:18
# 2020-10-14 10:25:00  EURUSD   sell  0.01  2020-10-14 10:08:18
#
#                               close_date  open_price  close_price  profits  \
# dt_point_holding
# 2020-10-14 10:05:00  2020-10-14 12:31:20     1.17321      1.17625    -3.04
# 2020-10-14 10:10:00  2020-10-14 12:31:20     1.17321      1.17625    -3.04
# 2020-10-14 10:15:00  2020-10-14 12:31:20     1.17321      1.17625    -3.04
# 2020-10-14 10:20:00  2020-10-14 12:31:20     1.17321      1.17625    -3.04
# 2020-10-14 10:25:00  2020-10-14 12:31:20     1.17321      1.17625    -3.04
#
#                      pips  commission  swaps  profits_calc  \
# dt_point_holding
# 2020-10-14 10:05:00 -30.4       -0.04    0.0        -0.344
# 2020-10-14 10:10:00 -30.4       -0.04    0.0        -0.344
# 2020-10-14 10:15:00 -30.4       -0.04    0.0        -0.344
# 2020-10-14 10:20:00 -30.4       -0.04    0.0        -0.344
# 2020-10-14 10:25:00 -30.4       -0.04    0.0        -0.344
#
#                      commission_by_pips  date_var  swap_per_date_var_and_pip  \
# dt_point_holding
# 2020-10-14 10:05:00                -0.4         0                        0.0
# 2020-10-14 10:10:00                -0.4         0                        0.0
# 2020-10-14 10:15:00                -0.4         0                        0.0
# 2020-10-14 10:20:00                -0.4         0                        0.0
# 2020-10-14 10:25:00                -0.4         0                        0.0
#
#                          open_date_mod_5     close_date_mod_5  \
# dt_point_holding
# 2020-10-14 10:05:00  2020-10-14 10:05:00  2020-10-14 12:30:00
# 2020-10-14 10:10:00  2020-10-14 10:05:00  2020-10-14 12:30:00
# 2020-10-14 10:15:00  2020-10-14 10:05:00  2020-10-14 12:30:00
# 2020-10-14 10:20:00  2020-10-14 10:05:00  2020-10-14 12:30:00
# 2020-10-14 10:25:00  2020-10-14 10:05:00  2020-10-14 12:30:00
#
#                             dt_range   dt_point_holding.1  dt_range_inter_num
# dt_point_holding
# 2020-10-14 10:05:00  0 days 02:25:00  2020-10-14 10:05:00                  30
# 2020-10-14 10:10:00  0 days 02:25:00  2020-10-14 10:10:00                  30
# 2020-10-14 10:15:00  0 days 02:25:00  2020-10-14 10:15:00                  30
# 2020-10-14 10:20:00  0 days 02:25:00  2020-10-14 10:20:00                  30
# 2020-10-14 10:25:00  0 days 02:25:00  2020-10-14 10:25:00                  30

# %% [markdown]
# ### 时间较长，思考怎么改成多线程跑

# %%
# %%time
# def func(row, yht_rc_df):
#     return len(yht_rc_df[yht_rc_df.index == row])

# yht_rc_df["hcount"] = yht_rc_df["dt_point_holding.1"].apply(func, yht_rc_df=yht_rc_df)
# yht_rc_df.head()

# %%
yht_rc_df[yht_rc_df.index == "2021-06-11 12:15:00"]
# Out:
#                      symbol action  lots            open_date  \
# 2021-06-11 12:15:00  0 days 00:20:00  2021-06-11 12:15:00                   5
# 2021-06-11 12:15:00  0 days 00:30:00  2021-06-11 12:15:00                   7
# 2021-06-11 12:15:00  0 days 00:30:00  2021-06-11 12:15:00                   7

# %%
from Utils.data_get_utils import get_duka_data_df
from Utils.data_process_utils import slice_df_by_timerange
from datetime import timedelta
from datetime import datetime

duka_5m_2020_df = get_duka_data_df("../data/EURUSD5_duka_2020.csv", "EURUSD")
duka_5m_2021_df = get_duka_data_df("../data/EURUSD5_duka_2021.csv", "EURUSD")
duka_5m_df = pd.concat([duka_5m_2020_df, duka_5m_2021_df])

rc_start_dt = pd.to_datetime(yht_rc_df.index).min() - timedelta(hours=2)
rc_end_dt = pd.to_datetime(yht_rc_df.index).max() + timedelta(hours=2)
print("slicing date range : (", rc_start_dt, ", ", rc_end_dt, ")")
duka_5m_df = slice_df_by_timerange(duka_5m_df, "datetime", rc_start_dt, rc_end_dt)

len(duka_5m_df)
# Out:
# slicing date range : ( 2020-10-14 08:05:00 ,  2021-07-09 05:05:00 )
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/tmp/ipykernel_287290/124967335.py in <module>
#      10 rc_end_dt = pd.to_datetime(yht_rc_df.index).max() + timedelta(hours=2)
#      11 print("slicing date range : (", rc_start_dt, ", ", rc_end_dt, ")")
# ---> 12 duka_5m_df = slice_df_by_timerange(duka_5m_df, "datetime", rc_start_dt, rc_end_dt)
#      13
#      14 len(duka_5m_df)
#
# NameError: name 'slice_df_by_timerange' is not defined

# %%
# %%time
from Utils.data_get_utils import calc_profit

def calc_rc_profits(row, yht_rc_df):
    cur_dt = row["datetime"].to_pydatetime()
    cur_holding_orders_df = yht_rc_df[yht_rc_df.index == cur_dt]
    
duka_5m_df.apply(calc_rc_profits, yht_rc_df=yht_rc_df, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/anaconda3/envs/rbsys/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8734             kwargs=kwargs,
#    8735         )
# -> 8736         return op.apply()
#    8737
#    8738     def applymap(
#
# ~/anaconda3/envs/rbsys/lib/python3.8/site-packages/pandas/core/apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ~/anaconda3/envs/rbsys/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#     803
#     804     def apply_standard(self):
# --> 805         results, res_index = self.apply_series_generator()
#     806
#     807         # wrap results
#
# ~/anaconda3/envs/rbsys/lib/python3.8/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     819             for i, v in enumerate(series_gen):
#     820                 # ignore SettingWithCopy here in case the user mutates
# --> 821                 results[i] = self.f(v)
#     822                 if isinstance(results[i], ABCSeries):
#     823                     # If we have a view on v, we need to make a copy because
#
# ~/anaconda3/envs/rbsys/lib/python3.8/site-packages/pandas/core/apply.py in f(x)
#     129
#     130             def f(x):
# --> 131                 return func(x, *args, **kwargs)
#     132
#     133         else:
#
# <timed exec> in calc_rc_profits(row, yht_rc_df)
#
# ~/anaconda3/envs/rbsys/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~/anaconda3/envs/rbsys/lib/python3.8/site-packages/pandas/core/arraylike.py in __eq__(self, other)
#      30     @unpack_zerodim_and_defer("__eq__")
#      31     def __eq__(self, other):
# ---> 32         return self._cmp_method(other, operator.eq)
#      33
#      34     @unpack_zerodim_and_defer("__ne__")
#
# ~/anaconda3/envs/rbsys/lib/python3.8/site-packages/pandas/core/indexes/base.py in _cmp_method(self, other, op)
#    6056             # don't pass MultiIndex
#    6057             with np.errstate(all="ignore"):
# -> 6058                 result = ops.comp_method_OBJECT_ARRAY(op, self._values, other)
#    6059
#    6060         else:
#
# ~/anaconda3/envs/rbsys/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      71         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      72     else:
# ---> 73         result = libops.scalar_compare(x.ravel(), y, op)
#      74     return result.reshape(x.shape)
#      75
#
# KeyboardInterrupt:
